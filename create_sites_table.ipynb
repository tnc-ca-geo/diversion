# %%
# Import data from sample files, modify, and export to new table

# %%
import pandas as pd
import os.path

# %%
insample = os.path.join( os.getcwd(), 'samples\\sites.csv' )
indata = os.path.join( os.getcwd(), '..', 'input_data\\stations.xlsx' )
outname = os.path.join( os.getcwd(), '..', 'sites.csv' )

# %%
df = pd.read_csv(insample)
df
# Out:
#   SiteCode                                           SiteName  Latitude  \
# 0  Siphon7  StatenX experimental station at Siphon 7 on St...   38.1698
#
#     Longitude LatLongDatumSRSName  Elevation_m  VerticalDatum  LocalX  LocalY  \
# 0 -121.527375               WGS84          NaN            NaN     NaN     NaN
#
#    LocalProjectionSRSName  PosAccuracy_m       State       County  \
# 0                     NaN            NaN  California  San Joaquin
#
#                                             Comments   SiteType
# 0  Site where multiple water meters are installed...  Diversion

# %%
# Modify the comment for siphon 7

new_comment = "Water Right ID: S018557; AG3000 Meter Serial Number: 032017001576; Telemetry ID: 001D0A8920278. " + df.at[0, 'Comments']
df.at[0, 'Comments'] = new_comment
df
# Out:
#   SiteCode                                           SiteName  Latitude  \
# 0  Siphon7  StatenX experimental station at Siphon 7 on St...   38.1698
#
#     Longitude LatLongDatumSRSName  Elevation_m  VerticalDatum  LocalX  LocalY  \
# 0 -121.527375               WGS84          NaN            NaN     NaN     NaN
#
#    LocalProjectionSRSName  PosAccuracy_m       State       County  \
# 0                     NaN            NaN  California  San Joaquin
#
#                                             Comments   SiteType
# 0  Water Right ID: S018557; AG3000 Meter Serial N...  Diversion

# %%
dfxl = pd.read_excel(open(indata,'rb'), sheet_name="sites")
dfxl
# Out:
#    SiteCode   SiteName  Latitude  Longitude LatLongDatumSRSName  Elevation_m  \
# 0  Siphon11  Siphon 11  38.15086 -121.53715               WGS84          NaN
# 1  Siphon15  Siphon 15  38.13763 -121.55673               WGS84          NaN
# 2  Siphon30  Siphon 30  38.16478 -121.49350               WGS84          NaN
# 3  Siphon39  Siphon 39  38.20172 -121.47739               WGS84          NaN
# 4  Siphon40  Siphon 40  38.20551 -121.48002               WGS84          NaN
#
#    VerticalDatum  LocalX  LocalY  LocalProjectionSRSName  PosAccuracy_m  \
# 0            NaN     NaN     NaN                     NaN            NaN
# 1            NaN     NaN     NaN                     NaN            NaN
# 2            NaN     NaN     NaN                     NaN            NaN
# 3            NaN     NaN     NaN                     NaN            NaN
# 4            NaN     NaN     NaN                     NaN            NaN
#
#         State       County                                           Comments  \
# 0  California  San Joaquin  Water Right ID: S018587; Meter Serial Number: ...
# 1  California  San Joaquin  Water Right ID: S018530; Meter Serial Number: ...
# 2  California  San Joaquin  Water Right ID: S018552; Meter Serial Number: ...
# 3  California  San Joaquin  Water Right ID: S018531; Meter Serial Number: ...
# 4  California  San Joaquin  Water Right ID: S018548; Meter Serial Number: ...
#
#     SiteType
# 0  Diversion
# 1  Diversion
# 2  Diversion
# 3  Diversion
# 4  Diversion

# %%
# Modify the sample table.  In this case, merge the sample data with the input data
df = df.append(dfxl, ignore_index=True)
df
# Out:
#    SiteCode                                           SiteName  Latitude  \
# 0   Siphon7  StatenX experimental station at Siphon 7 on St...  38.16980
# 1  Siphon11                                          Siphon 11  38.15086
# 2  Siphon15                                          Siphon 15  38.13763
# 3  Siphon30                                          Siphon 30  38.16478
# 4  Siphon39                                          Siphon 39  38.20172
# 5  Siphon40                                          Siphon 40  38.20551
#
#     Longitude LatLongDatumSRSName  Elevation_m  VerticalDatum  LocalX  LocalY  \
# 0 -121.527375               WGS84          NaN            NaN     NaN     NaN
# 1 -121.537150               WGS84          NaN            NaN     NaN     NaN
# 2 -121.556730               WGS84          NaN            NaN     NaN     NaN
# 3 -121.493500               WGS84          NaN            NaN     NaN     NaN
# 4 -121.477390               WGS84          NaN            NaN     NaN     NaN
# 5 -121.480020               WGS84          NaN            NaN     NaN     NaN
#
#    LocalProjectionSRSName  PosAccuracy_m       State       County  \
# 0                     NaN            NaN  California  San Joaquin
# 1                     NaN            NaN  California  San Joaquin
# 2                     NaN            NaN  California  San Joaquin
# 3                     NaN            NaN  California  San Joaquin
# 4                     NaN            NaN  California  San Joaquin
# 5                     NaN            NaN  California  San Joaquin
#
#                                             Comments   SiteType
# 0  Water Right ID: S018557; AG3000 Meter Serial N...  Diversion
# 1  Water Right ID: S018587; Meter Serial Number: ...  Diversion
# 2  Water Right ID: S018530; Meter Serial Number: ...  Diversion
# 3  Water Right ID: S018552; Meter Serial Number: ...  Diversion
# 4  Water Right ID: S018531; Meter Serial Number: ...  Diversion
# 5  Water Right ID: S018548; Meter Serial Number: ...  Diversion

# %%
# Save as a new text file
df.to_csv(outname, encoding='utf-8', index=False)
