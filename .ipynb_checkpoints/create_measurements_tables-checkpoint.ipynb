# %%
# Import measurement data from weatherlink files, modify, and export to new tables for each station

# %%
import pandas as pd
import plotly.plotly as py
import plotly.figure_factory as ff
import plotly.graph_objs as go
import os.path

# %%
insample = os.path.join( os.getcwd(), '..', 'samples\\IS203_EM.csv' )
indata = os.path.join( os.getcwd(), '..', 'input_data\\Staten_Island_-_East_Pumps_1-1-18_12-00_AM_1_Year_1546631222.csv' )
outname = os.path.join( os.getcwd(), '..', 'IS203_EM.csv' )

# %%
#Get headers (in two rows, starting with the third row)
headers = pd.read_csv(indata, skiprows=2,header=None,nrows=3)
headers
# Out:
#     0                                        1  \
# 0 NaN                             Siphon 7 SI
# 1 NaN  InnovaSonic 203 (100 Gallons per Pulse)
# 2 NaN                                   Port 1
#
#                                                    2  \
# 0                                       Siphon 7 SI
# 1  AG2000 -1200 -11/* -PxH GPM G (100 Gal per Pulse)
# 2                                             Port 2
#
#                                          3  \
# 0                             Siphon 7 SI
# 1  InnovaSonic 203 (100 Gallons per Pulse)
# 2                                   Port 3
#
#                                          4  \
# 0                                Siphon 30
# 1  InnovaSonic 203 (100 Gallons per Pulse)
# 2                                   Port 1
#
#                                          5  \
# 0                                Siphon 39
# 1  InnovaSonic 203 (100 Gallons per Pulse)
# 2                                   Port 1
#
#                                          6  \
# 0                                Siphon 40
# 1  InnovaSonic 203 (100 Gallons per Pulse)
# 2                                   Port 1
#
#                                          7  \
# 0                                Siphon 11
# 1  InnovaSonic 203 (100 Gallons per Pulse)
# 2                                   Port 1
#
#                                          8
# 0                                Siphon 15
# 1  InnovaSonic 203 (100 Gallons per Pulse)
# 2                                   Port 1

# %%
columns = ["Siphon7_IS_1", "Siphon7_AG_2", "Siphon7_IS_3"]
headers_row0 = headers.iloc[0].tolist()
k=[]
for i in headers_row0[1:]:
    j = i.replace(' ','')
    k.append(j)
columns.extend(k[3:])
columns
# Out:
# ['Siphon7_IS_1',
#  'Siphon7_AG_2',
#  'Siphon7_IS_3',
#  'Siphon30',
#  'Siphon39',
#  'Siphon40',
#  'Siphon11',
#  'Siphon15']

# %%
df = pd.read_csv(indata,skiprows=6,header=None,index_col=0, na_values="--")
df.columns = columns
df.head()
# Out:
#                  Siphon7_IS_1  Siphon7_AG_2  Siphon7_IS_3  Siphon30  Siphon39  \
# 0
# 1/1/18 12:00 AM           0.0           0.0           NaN       NaN       NaN
# 1/1/18 12:05 AM           0.0           0.0           NaN       NaN       NaN
# 1/1/18 12:10 AM           0.0           0.0           NaN       NaN       NaN
# 1/1/18 12:15 AM           0.0           0.0           NaN       NaN       NaN
# 1/1/18 12:20 AM           0.0           0.0           NaN       NaN       NaN
#
#                  Siphon40  Siphon11  Siphon15
# 0
# 1/1/18 12:00 AM       NaN       NaN       NaN
# 1/1/18 12:05 AM       NaN       NaN       NaN
# 1/1/18 12:10 AM       NaN       NaN       NaN
# 1/1/18 12:15 AM       NaN       NaN       NaN
# 1/1/18 12:20 AM       NaN       NaN       NaN

# %%
df = pd.read_csv(insample)
df
# Out:
#   SiteCode                                           SiteName  Latitude  \
# 0  Siphon7  StatenX experimental station at Siphon 7 on St...   38.1698
#
#     Longitude LatLongDatumSRSName  Elevation_m  VerticalDatum  LocalX  LocalY  \
# 0 -121.527375               WGS84          NaN            NaN     NaN     NaN
#
#    LocalProjectionSRSName  PosAccuracy_m       State       County  \
# 0                     NaN            NaN  California  San Joaquin
#
#                                             Comments   SiteType
# 0  Site where multiple water meters are installed...  Diversion

# %%
# Save as a new text file
df.to_csv(outname, encoding='utf-8')
