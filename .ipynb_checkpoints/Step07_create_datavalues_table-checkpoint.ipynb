# %%
# Import measurement data from weatherlink files, modify, and export to new tables for each station

# This page is very useful for time series manipulations:
# https://chrisalbon.com/python/data_wrangling/pandas_time_series_basics/

# %%
import pandas as pd
import numpy as np
import os.path
from datetime import datetime

# %%
year = '2019'
indata = os.path.join( os.getcwd(), '..', year, 'input_data', 'Staten_Island_-_East_Pumps_1-1-19_12-00_AM_1_Year_1580151855_v2.csv' )
indata2 = os.path.join( os.getcwd(), '..', year, 'input_data', 'Staten_Island_-_South_Pumps_1-1-19_12-00_AM_1_Year_1580172497_v2.csv' )
indata3 = os.path.join( os.getcwd(), '..', year, 'input_data', 'RMTNum1_191210_R_00.csv' )
indata4 = os.path.join( os.getcwd(), '..', year, 'input_data', 'RMTNum1_200218_R_00.csv' )
indata5 = os.path.join( os.getcwd(), '..', year, 'input_data', 'RMTNum1_191210_R_02.csv' )

outname = os.path.join( os.getcwd(), '..', year, 'DataValues.csv' )

# %% [markdown]
# ## Import datafile 1

# %%
#Get headers (in two rows, starting with the third row)
headers = pd.read_csv(indata, skiprows=2,header=None,nrows=3)
headers
# Out:
#    0                                        1   \
# 0 NaN                                Siphon 10
# 1 NaN  InnovaSonic 203 (100 Gallons per Pulse)
# 2 NaN                                   Port 1
#
#                                         2   \
# 0                                Siphon 36
# 1  InnovaSonic 203 (100 Gallons per Pulse)
# 2                                   Port 1
#
#                                         3   \
# 0                                Siphon 37
# 1  InnovaSonic 203 (100 Gallons per Pulse)
# 2                                   Port 1
#
#                                         4   \
# 0                                Siphon 38
# 1  InnovaSonic 203 (100 Gallons per Pulse)
# 2                                   Port 1
#
#                                         5   \
# 0                                 Siphon 4
# 1  InnovaSonic 203 (100 Gallons per Pulse)
# 2                                   Port 1
#
#                                         6   \
# 0                                 Siphon 5
# 1  InnovaSonic 203 (100 Gallons per Pulse)
# 2                                   Port 1
#
#                                         7   \
# 0                                 Siphon 6
# 1  InnovaSonic 203 (100 Gallons per Pulse)
# 2                                   Port 1
#
#                                         8   \
# 0                             Siphon 7 SI
# 1  InnovaSonic 203 (100 Gallons per Pulse)
# 2                                   Port 1
#
#                                                   9   \
# 0                                       Siphon 7 SI
# 1  AG2000 -1200 -11/* -PxH GPM G (100 Gal per Pulse)
# 2                                             Port 2
#
#                                         10
# 0                                 Siphon 9
# 1  InnovaSonic 203 (100 Gallons per Pulse)
# 2                                   Port 1

# %%
# Remove spaces from headers
headers_row0 = headers.iloc[0].tolist()
k=[]
for i in headers_row0[1:]:
    j = i.replace(' ','')
    k.append(j)
columns = k
columns
# Out:
# ['Siphon10',
#  'Siphon36',
#  'Siphon37',
#  'Siphon38',
#  'Siphon4',
#  'Siphon5',
#  'Siphon6',
#  'Siphon7SI',
#  'Siphon7SI',
#  'Siphon9']

# %%
# Provide more detail for Siphon 7 since it has two meters
columns.insert(7, 'Siphon7_IS')
columns.insert(8, 'Siphon7_AG')
columns.pop(9)
columns.pop(9)
columns
# Out:
# ['Siphon10',
#  'Siphon36',
#  'Siphon37',
#  'Siphon38',
#  'Siphon4',
#  'Siphon5',
#  'Siphon6',
#  'Siphon7_IS',
#  'Siphon7_AG',
#  'Siphon9']

# %%
#Import the data and create a date index
df = pd.read_csv(indata,skiprows=6,header=None,index_col=0, na_values="--")
df.index = pd.to_datetime(df.index) # Takes about 15 seconds
df.index.name = "LocalDateTime"
df.columns = columns
df.head()
# Out:
#                      Siphon10  Siphon36  Siphon37  Siphon38  Siphon4  Siphon5  \
# LocalDateTime
# 2019-01-01 00:00:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-01-01 00:05:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-01-01 00:10:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-01-01 00:15:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-01-01 00:20:00       0.0       0.0       0.0       0.0      NaN      NaN
#
#                      Siphon6  Siphon7_IS  Siphon7_AG  Siphon9
# LocalDateTime
# 2019-01-01 00:00:00      NaN         0.0         0.0      NaN
# 2019-01-01 00:05:00      NaN         0.0         0.0      NaN
# 2019-01-01 00:10:00      NaN         0.0         0.0      NaN
# 2019-01-01 00:15:00      NaN         0.0         0.0      NaN
# 2019-01-01 00:20:00      NaN         0.0         0.0      NaN

# %% [markdown]
# ## Import datafile 2

# %%
#Get headers (in two rows, starting with the third row)
headers2 = pd.read_csv(indata2, skiprows=2,header=None,nrows=3)
headers2
# Out:
#     0                                        1
# 0 NaN                                Siphon 21
# 1 NaN  InnovaSonic 203 (100 Gallons per Pulse)
# 2 NaN                                   Port 1

# %%
#Import the data and create a date index
df2 = pd.read_csv(indata2,skiprows=6,header=None,index_col=0, na_values="--")
df2.index = pd.to_datetime(df2.index) # Takes about 15 seconds
df2.index.name = "LocalDateTime"
df2.columns = ['Siphon21']
df2.head()
# Out:
#                      Siphon21
# LocalDateTime
# 2019-08-15 11:25:00         0
# 2019-08-15 11:30:00         0
# 2019-08-15 11:35:00         0
# 2019-08-15 11:40:00         0
# 2019-08-15 11:45:00         0

# %%
# Combine the dataframes
df = pd.merge(df, df2, on='LocalDateTime', how='left')
df.head()
# Out:
#                      Siphon10  Siphon36  Siphon37  Siphon38  Siphon4  Siphon5  \
# LocalDateTime
# 2019-01-01 00:00:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-01-01 00:05:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-01-01 00:10:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-01-01 00:15:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-01-01 00:20:00       0.0       0.0       0.0       0.0      NaN      NaN
#
#                      Siphon6  Siphon7_IS  Siphon7_AG  Siphon9  Siphon21
# LocalDateTime
# 2019-01-01 00:00:00      NaN         0.0         0.0      NaN       NaN
# 2019-01-01 00:05:00      NaN         0.0         0.0      NaN       NaN
# 2019-01-01 00:10:00      NaN         0.0         0.0      NaN       NaN
# 2019-01-01 00:15:00      NaN         0.0         0.0      NaN       NaN
# 2019-01-01 00:20:00      NaN         0.0         0.0      NaN       NaN

# %%
#Update column list
columns = list(df.columns.values)

# %% [markdown]
# ## Update dataframe to standard format

# %%
# Convert all data to gallons per minute
df = df/5

# %%
# OPTIONAL
#Check for daylight savings time issues
#Start 2am, March 10, 2019.  2am is converted to 3am
#End 2am, November 3, 2018. 2am data is missing
df['3-10-2019 01:00': '3-10-2019 04:00']
#df['11-3-2019 01:00': '11-3-2019 04:00']
# Out:
#                      Siphon10  Siphon36  Siphon37  Siphon38  Siphon4  Siphon5  \
# LocalDateTime
# 2019-03-10 01:00:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 01:05:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 01:10:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 01:15:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 01:20:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 01:25:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 01:30:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 01:35:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 01:40:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 01:45:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 01:50:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 01:55:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 03:00:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 03:05:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 03:10:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 03:15:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 03:20:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 03:25:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 03:30:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 03:35:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 03:40:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 03:45:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 03:50:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 03:55:00       0.0       0.0       0.0       0.0      NaN      NaN
# 2019-03-10 04:00:00       0.0       0.0       0.0       0.0      NaN      NaN
#
#                      Siphon6  Siphon7_IS  Siphon7_AG  Siphon9  Siphon21
# LocalDateTime
# 2019-03-10 01:00:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 01:05:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 01:10:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 01:15:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 01:20:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 01:25:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 01:30:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 01:35:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 01:40:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 01:45:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 01:50:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 01:55:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 03:00:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 03:05:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 03:10:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 03:15:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 03:20:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 03:25:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 03:30:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 03:35:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 03:40:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 03:45:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 03:50:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 03:55:00      NaN         0.0         0.0      NaN       NaN
# 2019-03-10 04:00:00      NaN         0.0         0.0      NaN       NaN

# %%
#Create UTC column
df['DateTimeUTC'] = df.index.tz_localize('US/Pacific', ambiguous='NaT').tz_convert('UTC')

# %%
#Create UTCOffset column
df['UTCOffset']  = (df['DateTimeUTC'] - df.index.tz_localize('UTC')).dt.seconds/(60*60)*-1

# %%
# Create the additional columns
df['QualityControlLevelCode'] = 0 # 0 is for raw data
df['SourceCode'] = "TNC2020"
df['CensorCode'] = "nc"
df['VariableCode'] = "GPM_5min"

# %%
# Reset the index to make a local date column
df = df.reset_index()

# %%
#Convert wide to long format
id_vars = ['LocalDateTime',
           'UTCOffset',
           'DateTimeUTC',
           'VariableCode',
           'SourceCode',
           'QualityControlLevelCode',
           'CensorCode'
          ]
value_vars = columns

df = pd.melt(df, id_vars=id_vars,value_vars=value_vars)

# %%
#Update the MethodCode field
#All sites use the same method except Siphon7_AG_2
df['MethodCode'] = "IS203_EM"
df.loc[df['variable'] == "Siphon7_AG", 'MethodCode'] = "AG3000_EM"

# %%
#Update the Site field
df.loc[df['variable'].isin(["Siphon7_AG", "Siphon7_IS"]), 'variable'] = "Siphon7"
df.rename(columns={'variable': 'SiteCode'}, inplace=True)

# %%
#Update DataValue field
df.rename(columns={'value': 'DataValue'}, inplace=True)

# %%
#Update Qualifier field
#More work needed to screen for outliers and missing values
df['QualifierCode'] = 0

# %%
# Remove the localization from the UTC column
df['DateTimeUTC'] = df['DateTimeUTC'].astype(str).str[:-6]

# %% [markdown]
# ## Import datafiles 3, 4, and 5

# %%
df3 = pd.read_csv(indata3, parse_dates=[['Date', 'Time']])
df4 = pd.read_csv(indata4, parse_dates=[['Date', 'Time']])
df3 = df3.append(df4)
df3['VariableCode'] = "GPM_8min"
df3
# Out:
#                 Date_Time  Index  Flow Rate(G/M)  Incremental Volume(G)  \
# 12590 2020-02-18 12:38:13  12590            0.00                   0.00
# 12591 2020-02-18 12:46:13  12591            0.00                   0.00
# 12592 2020-02-18 12:54:14  12592            0.00                   0.00
# 12593 2020-02-18 13:02:14  12593            0.00                   0.00
# 12594 2020-02-18 13:10:14  12594            0.00                   0.00
# 12595 2020-02-18 13:18:14  12595            0.00                   0.00
# 12596 2020-02-18 13:26:15  12596            0.00                   0.00
# 12597 2020-02-18 13:34:15  12597            0.00                   0.00
# 12598 2020-02-18 13:42:15  12598            0.00                   0.00
# 12599 2020-02-18 13:50:15  12599            0.00                   0.00
#
#        Totalized Volume(G) VariableCode
# 0                     0.00     GPM_8min
# 1                     0.00     GPM_8min
# 2                     0.00     GPM_8min
# 3                     0.00     GPM_8min
# 4                     0.00     GPM_8min
# 5                     0.00     GPM_8min
# 6                     0.00     GPM_8min
# 7                     0.00     GPM_8min
# 8                     0.00     GPM_8min
# 9                     0.00     GPM_8min
# 10                    0.00     GPM_8min
# 11                    0.00     GPM_8min
# 12                    0.00     GPM_8min
# 13                    0.00     GPM_8min
# 14                    0.00     GPM_8min
# 15                    0.00     GPM_8min
# 16                    0.00     GPM_8min
# 17                    0.00     GPM_8min
# 18                    0.00     GPM_8min
# 19                    0.00     GPM_8min
# 20                    0.00     GPM_8min
# 21                    0.00     GPM_8min
# 22                    0.00     GPM_8min
# 23                    0.00     GPM_8min
# 24                    0.00     GPM_8min
# 25                    0.00     GPM_8min
# 26                    0.00     GPM_8min
# 27                    0.00     GPM_8min
# 28                    0.00     GPM_8min
# 29                    0.00     GPM_8min
# ...                    ...          ...
# 12570                 0.00     GPM_8min
# 12571                 0.00     GPM_8min
# 12572                 0.00     GPM_8min
# 12573                 0.00     GPM_8min
# 12574              1384.53     GPM_8min
# 12575              1384.53     GPM_8min
# 12576              1384.53     GPM_8min
# 12577              1384.53     GPM_8min
# 12578              1384.53     GPM_8min
# 12579              1384.53     GPM_8min
# 12580              1384.53     GPM_8min
# 12581              1384.53     GPM_8min
# 12582              1384.53     GPM_8min
# 12583              1384.53     GPM_8min
# 12584              1384.53     GPM_8min
# 12585              1384.53     GPM_8min
# 12586              1384.53     GPM_8min
# 12587              1384.53     GPM_8min
# 12588              1384.53     GPM_8min
# 12589              1384.53     GPM_8min
# 12590              1384.53     GPM_8min
# 12591              1384.53     GPM_8min
# 12592              1384.53     GPM_8min
# 12593              1384.53     GPM_8min
# 12594              1384.53     GPM_8min
# 12595              1384.53     GPM_8min
# 12596              1384.53     GPM_8min
# 12597              1384.53     GPM_8min
# 12598              1384.53     GPM_8min
# 12599              1384.53     GPM_8min
#
# [78136 rows x 6 columns]

# %%
df5 = pd.read_csv(indata5, parse_dates=[['Date', 'Time']])
df5['VariableCode'] = "GPM_15sec"
df3 = df3.append(df5)
df3
# Out:
#               Date_Time  Index  Flow Rate(G/M)  Incremental Volume(G)  \
# 438 2019-12-10 12:54:26    438             0.0                    0.0
# 439 2019-12-10 12:54:41    439             0.0                    0.0
# 440 2019-12-10 12:54:56    440             0.0                    0.0
# 441 2019-12-10 12:55:11    441             0.0                    0.0
# 442 2019-12-10 12:55:26    442             0.0                    0.0
# 443 2019-12-10 12:55:41    443             0.0                    0.0
# 444 2019-12-10 12:55:56    444             0.0                    0.0
# 445 2019-12-10 12:56:11    445             0.0                    0.0
# 446 2019-12-10 12:56:26    446             0.0                    0.0
#
#      Totalized Volume(G) VariableCode
# 0                   0.00     GPM_8min
# 1                   0.00     GPM_8min
# 2                   0.00     GPM_8min
# 3                   0.00     GPM_8min
# 4                   0.00     GPM_8min
# 5                   0.00     GPM_8min
# 6                   0.00     GPM_8min
# 7                   0.00     GPM_8min
# 8                   0.00     GPM_8min
# 9                   0.00     GPM_8min
# 10                  0.00     GPM_8min
# 11                  0.00     GPM_8min
# 12                  0.00     GPM_8min
# 13                  0.00     GPM_8min
# 14                  0.00     GPM_8min
# 15                  0.00     GPM_8min
# 16                  0.00     GPM_8min
# 17                  0.00     GPM_8min
# 18                  0.00     GPM_8min
# 19                  0.00     GPM_8min
# 20                  0.00     GPM_8min
# 21                  0.00     GPM_8min
# 22                  0.00     GPM_8min
# 23                  0.00     GPM_8min
# 24                  0.00     GPM_8min
# 25                  0.00     GPM_8min
# 26                  0.00     GPM_8min
# 27                  0.00     GPM_8min
# 28                  0.00     GPM_8min
# 29                  0.00     GPM_8min
# ..                   ...          ...
# 417             79464.07    GPM_15sec
# 418             79464.07    GPM_15sec
# 419             79464.07    GPM_15sec
# 420             79464.07    GPM_15sec
# 421             79464.07    GPM_15sec
# 422             79464.07    GPM_15sec
# 423             79464.07    GPM_15sec
# 424             79464.07    GPM_15sec
# 425             79464.07    GPM_15sec
# 426             79464.07    GPM_15sec
# 427             79464.07    GPM_15sec
# 428             79464.07    GPM_15sec
# 429             79464.07    GPM_15sec
# 430             79464.07    GPM_15sec
# 431             79464.07    GPM_15sec
# 432             79464.07    GPM_15sec
# 433             79464.07    GPM_15sec
# 434             79464.07    GPM_15sec
# 435             79464.07    GPM_15sec
# 436             79464.07    GPM_15sec
# 437             79464.07    GPM_15sec
# 438             79464.07    GPM_15sec
# 439             79464.07    GPM_15sec
# 440             79464.07    GPM_15sec
# 441             79464.07    GPM_15sec
# 442             79464.07    GPM_15sec
# 443             79464.07    GPM_15sec
# 444             79464.07    GPM_15sec
# 445             79464.07    GPM_15sec
# 446             79464.07    GPM_15sec
#
# [78583 rows x 6 columns]

# %%
#Convert date_time to index
df3.index = df3.Date_Time
df3.index.name = "LocalDateTime"

# %%
# OPTIONAL
#Check for daylight savings time issues
#Start 2am, March 10, 2019.  2am is converted to 3am
#End 2am, November 3, 2019. 1am data is repeated.  Values are all 0 so no impact
#df3['3-10-2019 01:00': '3-10-2019 04:00']
    0.0         1.256863e+08     GPM_8min
# 2019-11-03 03:48:36                    0.0         1.256863e+08     GPM_8min
# 2019-11-03 03:56:37                    0.0         1.256863e+08     GPM_8min

# %%
#Create UTC column
df3['DateTimeUTC'] = df3.index.tz_localize('US/Pacific', ambiguous='NaT').tz_convert('UTC')

# %%
#Create UTCOffset column
df3['UTCOffset']  = (df3['DateTimeUTC'] - df3.index.tz_localize('UTC')).dt.seconds/(60*60)*-1

# %%
# Create the additional columns
df3['QualityControlLevelCode'] = 0 # 0 is for raw data
df3['SourceCode'] = "TNC2020"
df3['CensorCode'] = "nc"
df3['SiteCode'] = "Siphon7"
df3['MethodCode'] = "AG3000_DL"
df3['QualifierCode'] = 0

# %%
# Drop additional columns
df3 = df3.drop(['Date_Time', 'Index', 'Incremental Volume(G)', 'Totalized Volume(G)'], axis=1)

# %%
# Reset the index to make a local date column
df3 = df3.reset_index()

# %%
#Update DataValue field
df3.rename(columns={'Flow Rate(G/M)': 'DataValue'}, inplace=True)

# %%
df3.head()
# Out:
#         LocalDateTime  DataValue VariableCode               DateTimeUTC  \
# 0 2018-12-11 03:59:53        0.0     GPM_8min 2018-12-11 11:59:53+00:00
# 1 2018-12-11 04:07:53        0.0     GPM_8min 2018-12-11 12:07:53+00:00
# 2 2018-12-11 04:15:53        0.0     GPM_8min 2018-12-11 12:15:53+00:00
# 3 2018-12-11 04:23:53        0.0     GPM_8min 2018-12-11 12:23:53+00:00
# 4 2018-12-11 04:31:54        0.0     GPM_8min 2018-12-11 12:31:54+00:00
#
#    UTCOffset  QualityControlLevelCode SourceCode CensorCode SiteCode  \
# 0       -8.0                        0    TNC2020         nc  Siphon7
# 1       -8.0                        0    TNC2020         nc  Siphon7
# 2       -8.0                        0    TNC2020         nc  Siphon7
# 3       -8.0                        0    TNC2020         nc  Siphon7
# 4       -8.0                        0    TNC2020         nc  Siphon7
#
#   MethodCode  QualifierCode
# 0  AG3000_DL              0
# 1  AG3000_DL              0
# 2  AG3000_DL              0
# 3  AG3000_DL              0
# 4  AG3000_DL              0

# %%
#clip to 2019 only
mask = (df3['LocalDateTime'] >= '2019-1-1 00:00') & (df3['LocalDateTime'] < '2020-1-1 00:00')
df3 = df3.loc[mask]

# %%
# Remove the localization from the UTC column
df3['DateTimeUTC'] = df3['DateTimeUTC'].astype(str).str[:-6]

# %%
#Check the schema
print(df.dtypes)
print(df3.dtypes)
# Out:
# LocalDateTime              datetime64[ns]
# UTCOffset                         float64
# DateTimeUTC                        object
# VariableCode                       object
# SourceCode                         object
# QualityControlLevelCode             int64
# CensorCode                         object
# SiteCode                           object
# DataValue                         float64
# MethodCode                         object
# QualifierCode                       int64
# dtype: object
# LocalDateTime              datetime64[ns]
# DataValue                         float64
# VariableCode                       object
# DateTimeUTC                        object
# UTCOffset                         float64
# QualityControlLevelCode             int64
# SourceCode                         object
# CensorCode                         object
# SiteCode                           object
# MethodCode                         object
# QualifierCode                       int64
# dtype: object

# %%
#Append the dataframes
df_final = df.append(df3)

# %%
# Save as a new text file
df_final.to_csv(outname, encoding='utf-8',index=False)
